# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import time
import datetime

from dataset import train, val, test
from helper_functions import plot_loss, plot_accuracy, validation, cal_acc
# Out:
# C:\Users\rahul\AnacondaReal\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\rahul\AnacondaReal\lib\site-packages\numpy\.libs\libopenblas.noijjg62emaszi6nyurl6jbkm4evbgm7.gfortran-win_amd64.dll
# C:\Users\rahul\AnacondaReal\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\rahul\AnacondaReal\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
import trading_strategy as ts

# %%
from ui_backend import *

# %%
backend = Backend()
# Out:
# D:\sutd\Term 7\Deep Learning\Big_Project\Term7_Deep_Learning_BigProject\dataset.py:31: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   mean_deviation = typical_price.rolling(ndays).apply(lambda x: pd.Series(x).mad())
# D:\sutd\Term 7\Deep Learning\Big_Project\Term7_Deep_Learning_BigProject\dataset.py:296: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   mean_deviation = typical_price.rolling(ndays).apply(lambda x: pd.Series(x).mad())

# %%
backend.get_model_predictions()
backend.get_strategy_plot()

# %%
backend.get_individual_data_sample("2016-03-10")
# Out:
# (([196.67999267578125,
#    196.22999572753906,
#    198.2100067138672,
#    199.05999755859375,
#    199.8000030517578,
#    201.35000610351562,
#    201.07000732421875,
#    199.9199981689453,
#    199.7899932861328,
#    201.07000732421875],
#   [194.89999389648438,
#    193.3300018310547,
#    194.4499969482422,
#    197.25,
#    198.11000061035156,
#    199.02999877929688,
#    199.25,
#    198.2100067138672,
#    198.42999267578125,
#    197.3800048828125],
#   [195.08999633789062,
#    193.55999755859375,
#    198.11000061035156,
#    199.0,
#    199.77999877929688,
#    200.42999267578125,
#    200.58999633789062,
#    198.39999389648438,
#    199.3800048828125,
#    199.5399932861328],
#   [93.13607788085938,
#    27.3300838470459,
#    120.35855102539062,
#    120.55611419677734,
#    99.965576171875,
#    91.86250305175781,
#    78.2816162109375,
#    -54.91701889038086,
#    -42.90609359741211,
#    -30.990827560424805],
#   [116.69559478759766,
#    65.28681945800781,
#    144.62814331054688,
#    161.84593200683594,
#    139.32986450195312,
#    129.1926727294922,
#    99.70962524414062,
#    50.45248031616211,
#    49.29747772216797,
#    45.78762435913086],
#   [116.64163970947266,
#    85.99272155761719,
#    131.29345703125,
#    140.8861083984375,
#    138.23143005371094,
#    136.4048309326172,
#    122.81474304199219,
#    91.36002349853516,
#    89.43196105957031,
#    85.43021392822266],
#   [2.119840145111084,
#    2.0537402629852295,
#    2.629467010498047,
#    3.063631772994995,
#    3.5522444248199463,
#    3.904383659362793,
#    4.185720920562744,
#    4.280461311340332,
#    4.443319797515869,
#    4.431447505950928],
#   [0.7785561084747314,
#    1.1440049409866333,
#    1.4914194345474243,
#    1.8276342153549194,
#    2.162360191345215,
#    2.472923755645752,
#    2.7833974361419678,
#    3.0844521522521973,
#    3.359200954437256,
#    3.616046190261841],
#   [1.3412840366363525,
#    0.909735381603241,
#    1.138047456741333,
#    1.2359975576400757,
#    1.389884114265442,
#    1.4314597845077515,
#    1.4023233652114868,
#    1.1960090398788452,
#    1.0841188430786133,
#    0.8154013156890869]),
#  1,
#  1.0)
