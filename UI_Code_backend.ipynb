# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import time
import datetime

from dataset import train, val, test
from helper_functions import plot_loss, plot_accuracy, validation, cal_acc

# %%
import trading_strategy as ts

# %%
from ui_backend import *

# %%
backend = Backend()

# %%
backend.get_model_predictions()
backend.get_strategy_plot()
# Out:
# c:\Users\Charmaine\Desktop\Term7\dl\Term7_Deep_Learning_BigProject\ui_backend.py:47: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   out=self.act(out)

# %%
backend.get_individual_data_sample("2016-03-10")
# Out:
# (([196.67999267578125,
#    196.22999572753906,
#    198.2100067138672,
#    199.05999755859375,
#    199.8000030517578,
#    201.35000610351562,
#    201.07000732421875,
#    199.9199981689453,
#    199.7899932861328,
#    201.07000732421875],
#   [194.89999389648438,
#    193.3300018310547,
#    194.4499969482422,
#    197.25,
#    198.11000061035156,
#    199.02999877929688,
#    199.25,
#    198.2100067138672,
#    198.42999267578125,
#    197.3800048828125],
#   [195.08999633789062,
#    193.55999755859375,
#    198.11000061035156,
#    199.0,
#    199.77999877929688,
#    200.42999267578125,
#    200.58999633789062,
#    198.39999389648438,
#    199.3800048828125,
#    199.5399932861328],
#   [93.13607788085938,
#    27.3300838470459,
#    120.35855102539062,
#    120.55611419677734,
#    99.965576171875,
#    91.86250305175781,
#    78.2816162109375,
#    -54.91701889038086,
#    -42.90609359741211,
#    -30.990827560424805],
#   [116.69559478759766,
#    65.28681945800781,
# ...

# %%
backend.test1.train_date
# Out:
# 42     2016-03-04
# 43     2016-03-07
# 44     2016-03-08
# 45     2016-03-09
# 46     2016-03-10
#           ...
# 471    2017-11-14
# 472    2017-11-15
# 473    2017-11-16
# 474    2017-11-17
# 475    2017-11-20
# Name: Date, Length: 434, dtype: object
